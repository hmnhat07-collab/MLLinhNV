# %% [markdown]
# <a href="https://colab.research.google.com/github/hmnhat07-collab/MLLinhNV/blob/main/Hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyvi
# Out:
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pyvi) (1.6.1)
# Collecting sklearn-crfsuite (from pyvi)
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (3.6.0)
# Collecting python-crfsuite>=0.9.7 (from sklearn-crfsuite->pyvi)
#   Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (4.67.3)
# Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 37.2 MB/s eta 0:00:00
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.3 MB/s eta 0:00:00
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.12 pyvi-0.1.1 sklearn-crfsuite-0.5.0

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets import load_files
from pyvi import ViTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
NPUT = '/content/drive/MyDrive/MLThayLinh/news_vnexpress'
os.makedirs("images", exist_ok=True)

# %%
import os

INPUT = '/content/drive/MyDrive/MLThayLinh/news_vnexpress'

print("Các nhãn và số văn bản tương ứng trong dữ liệu:")
n = 0

for label in os.listdir(INPUT):
    label_path = os.path.join(INPUT, label)

    if os.path.isdir(label_path):
        count = len(os.listdir(label_path))
        print(f'{label}: {count}')
        n += count
    else:
        print(f' -> [Đã bỏ qua file rác]: {label}')

print(f"----------------------------------")
print(f"Tổng số văn bản hợp lệ: {n}")
# Out:
# Các nhãn và số văn bản tương ứng trong dữ liệu:
# suc-khoe: 162
# giao-duc: 105
#  -> [Đã bỏ qua file rác]: Bản sao của news_1135.zip
# the-thao: 173
# giai-tri: 201
# phap-luat: 59
# kinh-doanh: 262
# du-lich: 54
# thoi-su: 59
# khoa-hoc: 144
# doi-song: 120
# ----------------------------------
# Tổng số văn bản hợp lệ: 1339

# %%
data_train = load_files(container_path=INPUT, encoding="utf-8")
print('mapping:')
for i in range(len(data_train.target_names)):
    print(f'{data_train.target_names[i]} - {i}')
print(data_train.filenames[0:1])
print(data_train.target[0:1])
print(data_train.data[0:1])
print("\nTong so van ban : {}" .format(len(data_train.filenames)))
# Out:
# mapping:
# doi-song - 0
# du-lich - 1
# giai-tri - 2
# giao-duc - 3
# khoa-hoc - 4
# kinh-doanh - 5
# phap-luat - 6
# suc-khoe - 7
# the-thao - 8
# thoi-su - 9
# ['/content/drive/MyDrive/MLThayLinh/news_vnexpress/khoa-hoc/00133.txt']
# [4]
# ['Mời độc giả đặt câu hỏi tại đây\n']
#
# Tong so van ban : 1339

# %%
import requests
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline

url = "https://raw.githubusercontent.com/stopwords/vietnamese-stopwords/master/vietnamese-stopwords.txt"
response = requests.get(url)

stopwords_raw = response.text.split('\n')

stopwords = [x.strip().replace(" ", "_") for x in stopwords_raw if x.strip()]

print(f"So luong stopwords: {len(stopwords)}")
print(stopwords[:10])
module_count_vector = CountVectorizer(stop_words=stopwords)
model_rf_preprocess = Pipeline([
    ('vect', module_count_vector),
    ('tfidf', TfidfTransformer()),
])

data_preprocessed = model_rf_preprocess.fit_transform(data_train.data, data_train.target)

X = data_preprocessed
Y = data_train.target

print(f"\nSo luong tu trong tu dien: {len(module_count_vector.vocabulary_)}")
print(f"Kich thuoc du lieu sau khi xu ly: {X.shape}")
print(f"Kich thuoc nhan tuong ung : {Y.shape}")
# Out:
# So luong stopwords: 1942
# ['a_lô', 'a_ha', 'ai', 'ai_ai', 'ai_nấy', 'ai_đó', 'alô', 'amen', 'anh', 'anh_ấy']
#
# So luong tu trong tu dien: 12797
# Kich thuoc du lieu sau khi xu ly: (1339, 12797)
# Kich thuoc nhan tuong ung : (1339,)
